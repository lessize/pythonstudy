# %%
import os
import sys
import urllib.request
import urllib.parse
import json
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.by import By
import time
import re
import pandas as pd

# %%
client_id = "zCef739dSJ7Vgc0A6jXb"
client_secret = "HDOxDMIZ2m"
search_keyword = "선운산"
mountain_road = urllib.parse.quote(search_keyword)
display = 100

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)

contents = []

for start in range(1, 902, 100):
    url = f'https://openapi.naver.com/v1/search/blog?query={mountain_road}&display={display}&start={start}'
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if rescode == 200:
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        data_dict = json.loads(json_data)

        # "items" 키에 해당하는 값에서 "link" 키에 해당하는 값만 추출하여 리스트에 저장
        links = [item['link'] for item in data_dict['items']]
        print(start)

        # 각 블로그의 텍스트 가져오기
        for i in links:
            try:
                print(i)
                driver.get(i)
                time.sleep(2)  # 대기시간 변경 가능

                iframe = driver.find_element(By.ID , "mainFrame") # id가 mainFrame이라는 요소를 찾아내고 -> iframe임
                driver.switch_to.frame(iframe) # 이 iframe이 내가 찾고자하는 html을 포함하고 있는 내용

                source = driver.page_source
                html = BeautifulSoup(source, "html.parser")
                
                # 기사 텍스트만 가져오기
                content = html.select("div.se-main-container")
                #  list합치기
                content = ''.join(str(content))

                # html태그제거 및 텍스트 다듬기
                pattern1 = '<[^>]*>'
                content = re.sub(pattern=pattern1, repl='', string=content)
                pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
                content = content.replace(pattern2, '')
                content = content.replace('\n', '')
                content = content.replace('\u200b', '')
                contents.append(content)
            except:
                continue
    else:
        print("Error Code:", rescode)

news_df = pd.DataFrame({'content': contents})
news_df.to_csv(f'{search_keyword}.csv', index=False, encoding='utf-8-sig')

# 크롬 드라이버 종료
driver.quit()
# Out:
# https://blog.naver.com/jaejin0211/223364592992
# https://blog.naver.com/lss4989/20198216549
# https://blog.naver.com/be_strong32/223352143353
# https://blog.naver.com/phk581210/222166235782
# https://blog.naver.com/okyoky2000/222123012417
# https://blog.naver.com/jungbae1022/223233343713
# https://blog.naver.com/you5834/221993582981
# https://blog.naver.com/tlkim47/220224334621
# https://gogosan.tistory.com/1553
# https://blog.naver.com/jigaekkun/223371669296
# https://blog.naver.com/pst020666/223350971425
# https://bloomjda.net/2128910079
# https://blog.naver.com/cosan13/120027426700
# https://blog.naver.com/freemanksd/222190454209
# https://blog.naver.com/likethwind/223277781696
# https://blog.naver.com/babyksd/40166110119
# https://48324ekfmak.tistory.com/152
# https://blog.naver.com/jjy0822kr/221700278005
# https://blog.naver.com/squirrel56/223321455394
# 201
# https://blog.naver.com/pst020666/223367051318
# https://blog.naver.com/sunsky64/220939733117
# https://blog.naver.com/21yhlee/220513510447
# https://blog.naver.com/klad1/223275023497
# https://blog.naver.com/lipspig/221977916571
# https://blog.naver.com/ok3kch/221042747879
# https://blog.naver.com/nyz1835/223117175391
# https://blog.naver.com/phjoo5504/220290783884
# https://blog.naver.com/sang1154/220726146317
# https://blog.naver.com/kckdfo/70069573753
# https://blog.naver.com/hongjiklee10/223215509129
# https://blog.naver.com/cvcv5552/223221797699
# https://blog.naver.com/keh_kkh/223028332106
# https://blog.naver.com/lsd0961/220997232513
# https://blog.naver.com/koreainews/222872918934
# https://blog.naver.com/ch1180/130161696750
# https://blog.naver.com/koreainews/223165084400
# https://blog.naver.com/welaw2354/223012593194

# %%
client_id = "zCef739dSJ7Vgc0A6jXb"
client_secret = "HDOxDMIZ2m"
search_keyword = "대청봉"
mountain_road = urllib.parse.quote(search_keyword)
display = 100

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)

contents = []

for start in range(1, 902, 100):
    url = f'https://openapi.naver.com/v1/search/blog?query={mountain_road}&display={display}&start={start}'
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if rescode == 200:
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        data_dict = json.loads(json_data)

        # "items" 키에 해당하는 값에서 "link" 키에 해당하는 값만 추출하여 리스트에 저장
        links = [item['link'] for item in data_dict['items']]
        print(start)

        # 각 블로그의 텍스트 가져오기
        for i in links:
            try:
                print(i)
                driver.get(i)
                time.sleep(2)  # 대기시간 변경 가능

                iframe = driver.find_element(By.ID , "mainFrame") # id가 mainFrame이라는 요소를 찾아내고 -> iframe임
                driver.switch_to.frame(iframe) # 이 iframe이 내가 찾고자하는 html을 포함하고 있는 내용

                source = driver.page_source
                html = BeautifulSoup(source, "html.parser")
                
                # 기사 텍스트만 가져오기
                content = html.select("div.se-main-container")
                #  list합치기
                content = ''.join(str(content))

                # html태그제거 및 텍스트 다듬기
                pattern1 = '<[^>]*>'
                content = re.sub(pattern=pattern1, repl='', string=content)
                pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
                content = content.replace(pattern2, '')
                content = content.replace('\n', '')
                content = content.replace('\u200b', '')
                contents.append(content)
            except:
                continue
    else:
        print("Error Code:", rescode)

news_df = pd.DataFrame({'content': contents})
news_df.to_csv(f'{search_keyword}.csv', index=False, encoding='utf-8-sig')

# 크롬 드라이버 종료
driver.quit()

# %%
client_id = "zCef739dSJ7Vgc0A6jXb"
client_secret = "HDOxDMIZ2m"
search_keyword = "성인봉"
mountain_road = urllib.parse.quote(search_keyword)
display = 100

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)

contents = []

for start in range(1, 902, 100):
    url = f'https://openapi.naver.com/v1/search/blog?query={mountain_road}&display={display}&start={start}'
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if rescode == 200:
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        data_dict = json.loads(json_data)

        # "items" 키에 해당하는 값에서 "link" 키에 해당하는 값만 추출하여 리스트에 저장
        links = [item['link'] for item in data_dict['items']]
        print(start)

        # 각 블로그의 텍스트 가져오기
        for i in links:
            try:
                print(i)
                driver.get(i)
                time.sleep(2)  # 대기시간 변경 가능

                iframe = driver.find_element(By.ID , "mainFrame") # id가 mainFrame이라는 요소를 찾아내고 -> iframe임
                driver.switch_to.frame(iframe) # 이 iframe이 내가 찾고자하는 html을 포함하고 있는 내용

                source = driver.page_source
                html = BeautifulSoup(source, "html.parser")
                
                # 기사 텍스트만 가져오기
                content = html.select("div.se-main-container")
                #  list합치기
                content = ''.join(str(content))

                # html태그제거 및 텍스트 다듬기
                pattern1 = '<[^>]*>'
                content = re.sub(pattern=pattern1, repl='', string=content)
                pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
                content = content.replace(pattern2, '')
                content = content.replace('\n', '')
                content = content.replace('\u200b', '')
                contents.append(content)
            except:
                continue
    else:
        print("Error Code:", rescode)

news_df = pd.DataFrame({'content': contents})
news_df.to_csv(f'{search_keyword}.csv', index=False, encoding='utf-8-sig')

# 크롬 드라이버 종료
driver.quit()

# %%
client_id = "zCef739dSJ7Vgc0A6jXb"
client_secret = "HDOxDMIZ2m"
search_keyword = "소백산"
mountain_road = urllib.parse.quote(search_keyword)
display = 100

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)

contents = []

for start in range(1, 902, 100):
    url = f'https://openapi.naver.com/v1/search/blog?query={mountain_road}&display={display}&start={start}'
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if rescode == 200:
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        data_dict = json.loads(json_data)

        # "items" 키에 해당하는 값에서 "link" 키에 해당하는 값만 추출하여 리스트에 저장
        links = [item['link'] for item in data_dict['items']]
        print(start)

        # 각 블로그의 텍스트 가져오기
        for i in links:
            try:
                print(i)
                driver.get(i)
                time.sleep(2)  # 대기시간 변경 가능

                iframe = driver.find_element(By.ID , "mainFrame") # id가 mainFrame이라는 요소를 찾아내고 -> iframe임
                driver.switch_to.frame(iframe) # 이 iframe이 내가 찾고자하는 html을 포함하고 있는 내용

                source = driver.page_source
                html = BeautifulSoup(source, "html.parser")
                
                # 기사 텍스트만 가져오기
                content = html.select("div.se-main-container")
                #  list합치기
                content = ''.join(str(content))

                # html태그제거 및 텍스트 다듬기
                pattern1 = '<[^>]*>'
                content = re.sub(pattern=pattern1, repl='', string=content)
                pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
                content = content.replace(pattern2, '')
                content = content.replace('\n', '')
                content = content.replace('\u200b', '')
                contents.append(content)
            except:
                continue
    else:
        print("Error Code:", rescode)

news_df = pd.DataFrame({'content': contents})
news_df.to_csv(f'{search_keyword}.csv', index=False, encoding='utf-8-sig')

# 크롬 드라이버 종료
driver.quit()

# %%
client_id = "zCef739dSJ7Vgc0A6jXb"
client_secret = "HDOxDMIZ2m"
search_keyword = "소요산"
mountain_road = urllib.parse.quote(search_keyword)
display = 100

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)

contents = []

for start in range(1, 902, 100):
    url = f'https://openapi.naver.com/v1/search/blog?query={mountain_road}&display={display}&start={start}'
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if rescode == 200:
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        data_dict = json.loads(json_data)

        # "items" 키에 해당하는 값에서 "link" 키에 해당하는 값만 추출하여 리스트에 저장
        links = [item['link'] for item in data_dict['items']]
        print(start)

        # 각 블로그의 텍스트 가져오기
        for i in links:
            try:
                print(i)
                driver.get(i)
                time.sleep(2)  # 대기시간 변경 가능

                iframe = driver.find_element(By.ID , "mainFrame") # id가 mainFrame이라는 요소를 찾아내고 -> iframe임
                driver.switch_to.frame(iframe) # 이 iframe이 내가 찾고자하는 html을 포함하고 있는 내용

                source = driver.page_source
                html = BeautifulSoup(source, "html.parser")
                
                # 기사 텍스트만 가져오기
                content = html.select("div.se-main-container")
                #  list합치기
                content = ''.join(str(content))

                # html태그제거 및 텍스트 다듬기
                pattern1 = '<[^>]*>'
                content = re.sub(pattern=pattern1, repl='', string=content)
                pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
                content = content.replace(pattern2, '')
                content = content.replace('\n', '')
                content = content.replace('\u200b', '')
                contents.append(content)
            except:
                continue
    else:
        print("Error Code:", rescode)

news_df = pd.DataFrame({'content': contents})
news_df.to_csv(f'{search_keyword}.csv', index=False, encoding='utf-8-sig')

# 크롬 드라이버 종료
driver.quit()

# %%
client_id = "zCef739dSJ7Vgc0A6jXb"
client_secret = "HDOxDMIZ2m"
search_keyword = "속리산"
mountain_road = urllib.parse.quote(search_keyword)
display = 100

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)

contents = []

for start in range(1, 902, 100):
    url = f'https://openapi.naver.com/v1/search/blog?query={mountain_road}&display={display}&start={start}'
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if rescode == 200:
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        data_dict = json.loads(json_data)

        # "items" 키에 해당하는 값에서 "link" 키에 해당하는 값만 추출하여 리스트에 저장
        links = [item['link'] for item in data_dict['items']]
        print(start)

        # 각 블로그의 텍스트 가져오기
        for i in links:
            try:
                print(i)
                driver.get(i)
                time.sleep(2)  # 대기시간 변경 가능

                iframe = driver.find_element(By.ID , "mainFrame") # id가 mainFrame이라는 요소를 찾아내고 -> iframe임
                driver.switch_to.frame(iframe) # 이 iframe이 내가 찾고자하는 html을 포함하고 있는 내용

                source = driver.page_source
                html = BeautifulSoup(source, "html.parser")
                
                # 기사 텍스트만 가져오기
                content = html.select("div.se-main-container")
                #  list합치기
                content = ''.join(str(content))

                # html태그제거 및 텍스트 다듬기
                pattern1 = '<[^>]*>'
                content = re.sub(pattern=pattern1, repl='', string=content)
                pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
                content = content.replace(pattern2, '')
                content = content.replace('\n', '')
                content = content.replace('\u200b', '')
                contents.append(content)
            except:
                continue
    else:
        print("Error Code:", rescode)

news_df = pd.DataFrame({'content': contents})
news_df.to_csv(f'{search_keyword}.csv', index=False, encoding='utf-8-sig')

# 크롬 드라이버 종료
driver.quit()

# %%
client_id = "zCef739dSJ7Vgc0A6jXb"
client_secret = "HDOxDMIZ2m"
search_keyword = "신불산"
mountain_road = urllib.parse.quote(search_keyword)
display = 100

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)

contents = []

for start in range(1, 902, 100):
    url = f'https://openapi.naver.com/v1/search/blog?query={mountain_road}&display={display}&start={start}'
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id", client_id)
    request.add_header("X-Naver-Client-Secret", client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if rescode == 200:
        response_body = response.read()
        json_data = response_body.decode('utf-8')
        data_dict = json.loads(json_data)

        # "items" 키에 해당하는 값에서 "link" 키에 해당하는 값만 추출하여 리스트에 저장
        links = [item['link'] for item in data_dict['items']]
        print(start)

        # 각 블로그의 텍스트 가져오기
        for i in links:
            try:
                print(i)
                driver.get(i)
                time.sleep(2)  # 대기시간 변경 가능

                iframe = driver.find_element(By.ID , "mainFrame") # id가 mainFrame이라는 요소를 찾아내고 -> iframe임
                driver.switch_to.frame(iframe) # 이 iframe이 내가 찾고자하는 html을 포함하고 있는 내용

                source = driver.page_source
                html = BeautifulSoup(source, "html.parser")
                
                # 기사 텍스트만 가져오기
                content = html.select("div.se-main-container")
                #  list합치기
                content = ''.join(str(content))

                # html태그제거 및 텍스트 다듬기
                pattern1 = '<[^>]*>'
                content = re.sub(pattern=pattern1, repl='', string=content)
                pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
                content = content.replace(pattern2, '')
                content = content.replace('\n', '')
                content = content.replace('\u200b', '')
                contents.append(content)
            except:
                continue
    else:
        print("Error Code:", rescode)

news_df = pd.DataFrame({'content': contents})
news_df.to_csv(f'{search_keyword}.csv', index=False, encoding='utf-8-sig')

# 크롬 드라이버 종료
driver.quit()
