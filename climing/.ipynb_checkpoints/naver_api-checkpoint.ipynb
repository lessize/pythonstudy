# %%
import os
import sys
import urllib.request
import pandas as pd
scroll_data = input('검색할 값을 입력해 주세요. :')
client_id = "ShIovNz7SXGAFNygBoVx"
client_secret = "1Gh1DzPsn3"
encText = urllib.parse.quote(scroll_data)
url = "https://openapi.naver.com/v1/search/blog?query=" + encText # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)

log = response_body.decode('utf-8')
# Out:
# 검색할 값을 입력해 주세요. :등산로
# {
# 	"lastBuildDate":"Mon, 08 Apr 2024 16:54:27 +0900",
# 	"total":1070490,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"아차산 주차장(아차산역 및 고구려대장간마을) 5곳, <b>등산로<\/b> 입구",
# 			"link":"https:\/\/blog.naver.com\/bonokebi1202\/223396146893",
# 			"description":"차량 가지고 아차산 등산하실 때 알아두면 좋은 아차산 주차장 5곳 그리고 <b>등산로<\/b> 입구 정리해 볼까... 사찰 옆에 <b>등산로<\/b> 입구가 있습니다. 기원정사 사찰 외에도 <b>등산로<\/b> 입구가 또 있는데요. 바로 여기!!!... ",
# 			"bloggername":"산타는 고은이",
# 			"bloggerlink":"blog.naver.com\/bonokebi1202",
# 			"postdate":"20240326"
# 		},
# 		{
# 			"title":"쉽다던 아차산 <b>등산로<\/b>, 광나루역에서 사가정역까지",
# 			"link":"https:\/\/blog.naver.com\/dmlgml76\/223251154754",
# 			"description":"아차산<b>등산로<\/b> 입구 만남의 광장이다. 우측에 이동식 화장실 있어서 미리 해결. 생각보다 깨끗해서... <b>등산로<\/b> 같기도 공원같기도 한... 보루같은 유적지들이 있어서 그런것 같기도 하고. 여기가 정상~ 아니고요~ 탁... ",
# 			"bloggername":"1% 다르게...",
# 			"bloggerlink":"blog.naver.com\/dmlgml76",
# 			"postdate":"20231031"
# 		},
# 		{
# 			"title":"동계라 막혀있던 홍천 팔봉산 관광지 <b>등산로<\/b> 캠핑장 유원지 모습",
# 			"link":"https:\/\/blog.naver.com\/21140427\/223346883891",
# 			"description":"동계 <b>등산로<\/b> 전면 통제 기간 공유 팔봉산유원지  막혀있어 한적했던 홍천 캠핑장 모습 사진*글\/바리형... 캠핑장부터 <b>등산로<\/b>까지 통제상태라 공유 차 포스팅해요. 홍천 팔봉산관광지  주 소 : 강원 홍천군... ",
# 			"bloggername":"바리형 믿고 따라와 ✈️",
# 			"bloggerlink":"blog.naver.com\/21140427",
# 			"postdate":"20240207"
# 		},
# 		{
# 			"title":"창녕 화왕산 등산 가을억새로 유명한 화왕산 자하곡1<b>등산로<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/qor9474\/223267693696",
# 			"description":"(토) 장소 : 창녕 화왕산 날씨 : 코스 : 자하곡매표소주차장-자하곡1<b>등산로<\/b>-생명의숲-자하정-배바위-화왕산정상-자하곡3<b>등산로<\/b>-도성암-자하곡매표소주차장(원점회귀) 거리 : 8.08㎞ 시간 : 4시간 41분(쉬엄쉬엄)... ",
# 			"bloggername":"바람의 소리",
# 			"bloggerlink":"blog.naver.com\/qor9474",
# 			"postdate":"20231117"
# 		},
# 		{
# 			"title":"강화도 마니산 등산코스 함허동천 참성대 최단 <b>등산로<\/b>",
# 			"link":"https:\/\/blog.naver.com\/chs153chs\/223398086295",
# 			"description":"인천 강화도 마니산의 최단 등산코스는 아니지만 함허동천 <b>등산로<\/b>로 참성대까지 후기 아직도... 강화도 마니산 최단 등산코스 중 함허동천 <b>등산로<\/b>와 참성대까지 포스팅을 정리해 보았습니다. 요 약 역사를... ",
# 			"bloggername":"걷는러너 여행과 등산 트레일 러닝",
# 			"bloggerlink":"blog.naver.com\/chs153chs",
# 			"postdate":"20240328"
# 		},
# 		{
# 			"title":"군포시 수리산  산림욕장 황톳길 중앙 도서관 방면 <b>등산로<\/b>를... ",
# 			"link":"https:\/\/blog.naver.com\/rndsoehd112\/223406304080",
# 			"description":"군포시 수리산에 위치한 수리산 산림욕장 황톳길을 중앙 도서관 방면에서 시작하는 <b>등산로<\/b> 코스에서... 군포시 중앙 도서관 방면에서 시작하는 수리산 <b>등산로<\/b> 코스는 대중교통으로는 1호선의 경우에는 금정역... ",
# 			"bloggername":"인생이 즐겁다.",
# 			"bloggerlink":"blog.naver.com\/rndsoehd112",
# 			"postdate":"20240405"
# 		},
# 		{
# 			"title":"서울근교 원적산 등산코스 영원사 들머리 주차 <b>등산로<\/b>... ",
# 			"link":"https:\/\/blog.naver.com\/rokag4\/223387920566",
# 			"description":"열리고 <b>등산로<\/b>도 쉽다는 말이 있어 동생과 함게 찾아갔다. 하지만!!! 영원사 들머리로 하는 원적산... 원적산 등산코스 <b>등산로<\/b> 상세 요약 ( 2024년 03월 16일 봄 산행 기준) 정개산, 원적산 <b>등산로<\/b> 안내 영원사... ",
# 			"bloggername":"팔도정복 하러 온 잠비",
# 			"bloggerlink":"blog.naver.com\/rokag4",
# 			"postdate":"20240319"
# 		},
# 		{
# 			"title":"[섬 그리고 산] 진도 접도 웰빙<b>등산로<\/b> 봄맞이 트레킹!",
# 			"link":"https:\/\/blog.naver.com\/khd4312\/223379581876",
# 			"description":"10 산행코스: 여미주차장 ~ 접도 웰빙<b>등산로<\/b>입구 ~ 남망산(쥐바위) ~ 병풍바위 ~ 선달봉 ~ 선달봉삼거리... 접도웰빙<b>등산로<\/b> 섬이지만 육지와 다리로 연결된 진도에서 다시 다리로 연결된 접도까지 섬이지만 이제는... ",
# 			"bloggername":"배가본드 내 인생",
# 			"bloggerlink":"blog.naver.com\/khd4312",
# 			"postdate":"20240311"
# 		},
# 		{
# 			"title":"등린이 일지.2 | 파주 파평산 산림공원 <b>등산로<\/b> 정보",
# 			"link":"https:\/\/blog.naver.com\/khannieandblues\/223350515082",
# 			"description":"등린이 탈출기 스따뜨 경기도 파주시 파평면에 위치한 파평산 총평: 만만치 않았던 아직은 겨울이구나 초입에 산도령을(?) 만나면 맞게 가고있슴 한서방이 찾아준 파평산 <b>등산로<\/b> 고고싱 지도에는 <b>등산로<\/b>1,2,3,4가... ",
# 			"bloggername":"~",
# 			"bloggerlink":"blog.naver.com\/khannieandblues",
# 			"postdate":"20240211"
# 		},
# 		{
# 			"title":"부산 기장 석은덤 병산숲길 <b>등산로<\/b> 산행 후기",
# 			"link":"https:\/\/blog.naver.com\/unilove012\/223308164071",
# 			"description":"길이 험하고 헷갈린다고 해서 갈까 말까 고민하다가 최근에 <b>등산로<\/b>를 정비했다는 글을 보고 다녀왔다.... 석은덤 <b>등산로<\/b>는 해운대컨트리클럽 표지판 옆에 있다. 차 타고 올라가는 경우 주차도 여기에 하면 됨.... ",
# 			"bloggername":"심주부 여행일기",
# 			"bloggerlink":"blog.naver.com\/unilove012",
# 			"postdate":"20231231"
# 		}
# 	]
# }

# %%
from bs4 import BeautifulSoup
import requests
import re
import time
import os
import sys
import urllib.request
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd

# 웹드라이버 설정
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)
# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용


# Naver API key 입력
client_id = "ShIovNz7SXGAFNygBoVx"
client_secret = "1Gh1DzPsn3"


# selenium으로 검색 페이지 불러오기 #
naver_urls = []
postdate = []
titles = []

# 검색어 입력
keword = input("검색할 키워드를 입력해주세요:")
encText = urllib.parse.quote(keword)

# 검색을 끝낼 페이지 입력
end = input("\n크롤링을 끝낼 위치를 입력해주세요. (기본값:1, 최대값:100):")  
if end == "":
    end = 1
else:
    end = int(end)
print("\n 1 ~ ", end, "페이지 까지 크롤링을 진행 합니다")

# 한번에 가져올 페이지 입력
display = input("\n한번에 가져올 페이지 개수를 입력해주세요.(기본값:10, 최대값: 100):")
if display == "":
    display = 10
else:
    display = int(display)
print("\n한번에 가져올 페이지 : ", display, "페이지")


for start in range(end):
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&start=" + str(start+1) + "&display=" + str(display+1) # JSON 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        
        data = json.loads(response_body.decode('utf-8'))['items']
        for row in data:
            if('blog.naver' in row['link']):
                naver_urls.append(row['link'])
                postdate.append(row['postdate'])
                title = row['title']
                # html태그제거
                pattern1 = '<[^>]*>'
                title = re.sub(pattern=pattern1, repl='', string=title)
                titles.append(title)
        time.sleep(2)
    else:
        print("Error Code:" + rescode)


for i in naver_urls:
    print(i)
for i in titles:
    print(i)
# Out:
# 검색할 키워드를 입력해주세요:등산로
#
# 크롤링을 끝낼 위치를 입력해주세요. (기본값:1, 최대값:100):
#
#  1 ~  1 페이지 까지 크롤링을 진행 합니다
#
# 한번에 가져올 페이지 개수를 입력해주세요.(기본값:10, 최대값: 100):
#
# 한번에 가져올 페이지 :  10 페이지
# https://blog.naver.com/bonokebi1202/223396146893
# https://blog.naver.com/dmlgml76/223251154754
# https://blog.naver.com/21140427/223346883891
# https://blog.naver.com/qor9474/223267693696
# https://blog.naver.com/chs153chs/223398086295
# https://blog.naver.com/rndsoehd112/223406304080
# https://blog.naver.com/rokag4/223387920566
# https://blog.naver.com/khd4312/223379581876
# https://blog.naver.com/khannieandblues/223350515082
# https://blog.naver.com/unilove012/223308164071
# https://blog.naver.com/sexysharon/223258673069
# 아차산 주차장(아차산역 및 고구려대장간마을) 5곳, 등산로 입구
# 쉽다던 아차산 등산로, 광나루역에서 사가정역까지
# 동계라 막혀있던 홍천 팔봉산 관광지 등산로 캠핑장 유원지 모습
# 창녕 화왕산 등산 가을억새로 유명한 화왕산 자하곡1등산로...
# 강화도 마니산 등산코스 함허동천 참성대 최단 등산로
# 군포시 수리산  산림욕장 황톳길 중앙 도서관 방면 등산로를...
# 서울근교 원적산 등산코스 영원사 들머리 주차 등산로...
# [섬 그리고 산] 진도 접도 웰빙등산로 봄맞이 트레킹!
# 등린이 일지.2 | 파주 파평산 산림공원 등산로 정보
# 부산 기장 석은덤 병산숲길 등산로 산행 후기
# 경기도 용인 석성산 단풍 등산로 등산코스 지도

# %%
from bs4 import BeautifulSoup
import requests
import re
import time
import os
import sys
import urllib.request
import json
from selenium import webdriver
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.keys import Keys
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.rc('font',family='Malgun Gothic') 
plt.rc('axes',unicode_minus=False)

df = pd.read_json('mountain_100.json',encoding='UTF-8')
df = pd.json_normalize(df['response']['body']['items']['item'])
df = df.rename(columns={'lot': '경도', 'frtrlId': '아이디','ctpvNm':'시도명','crtrDt':'데이터추출일시','aslAltide':'해발고도','mtnCd':'산코드','addrNm':'주소','frtrlNm':'산명','lat':'위도'
                       })

# 웹드라이버 설정
options = webdriver.ChromeOptions()
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option("useAutomationExtension", False)

# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용
driver = webdriver.Chrome()
driver.implicitly_wait(3)
# 버전에 상관 없이 os에 설치된 크롬 브라우저 사용


# Naver API key 입력
client_id = "ShIovNz7SXGAFNygBoVx"
client_secret = "1Gh1DzPsn3"


# selenium으로 검색 페이지 불러오기 #
naver_urls = []
postdate = []
titles = []



# 검색을 끝낼 페이지 입력
menu = input('100대 명산 채크 [명산]/ 일반 검색 [Enter]')

if(menu=='명산'):
    # 검색어 입력
    keword = input("검색할 키워드를 입력해주세요:")
    encText = urllib.parse.quote(keword)
    farst = input("\n크롤링을 시작 위치를 입력해주세요. (기본값:1, 최대값:100):")  
    if farst == "":
        farst = 1
    else:
        end = int(end)
    end = input("\n반복될 카운팅을 입력해주세요. (기본값:1, 최대값:100):")  
    if end == "":
        end = 1
    else:
        end = int(end)
    print(farst," ~",int(farst) + end, "페이지 까지 크롤링을 진행 합니다")
else:
    loopend = 1
    keword = input("검색할 키워드를 입력해주세요:")
    encText = urllib.parse.quote(keword)
    farst = input("\n크롤링을 시작 위치를 입력해주세요. (기본값:1, 최대값:100):")  
    if farst == "":
        farst = 1
    else:
        end = int(end)
    end = input("\n시작부터 마지막 위치 입력해주세요. (기본값:1, 최대값:100):")  
    if end == "":
        end = 1
    else:
        end = int(end)
    print(farst," ~",int(farst) + end, "페이지 까지 크롤링을 진행 합니다")

    
# 한번에 가져올 페이지 입력
display = input("\n한번에 가져올 페이지 개수를 입력해주세요.(기본값:10, 최대값: 100):")
if display == "":
    display = 10
else:
    display = int(display)
print("\n한번에 가져올 페이지 : ", display, "페이지")
namedata = keword


for start in range(end):
    url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&start=" + str(start+1+int(farst)) + "&display=" + str(display+1) # JSON 결과
    request = urllib.request.Request(url)
    request.add_header("X-Naver-Client-Id",client_id)
    request.add_header("X-Naver-Client-Secret",client_secret)
    response = urllib.request.urlopen(request)
    rescode = response.getcode()
    if(rescode==200):
        response_body = response.read()
        
        data = json.loads(response_body.decode('utf-8'))['items']
        for row in data:
            if('blog.naver' in row['link']):
                naver_urls.append(row['link'])
                postdate.append(row['postdate'])
                title = row['title']
                # html태그제거
                pattern1 = '<[^>]*>'
                title = re.sub(pattern=pattern1, repl='', string=title)
                titles.append(title)
        time.sleep(2)
    else:
        print("Error Code:" + rescode)
    farst = int(farst)  
    display = int(display)
    farst += display

###naver 기사 본문 및 제목 가져오기###

# ConnectionError방지
headers = {"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) Chrome/98.0.4758.102"}


contents = []
comments_texts = []
while(True) :
    try:
        for i in naver_urls:
            print(i)
            driver.get(i)
            time.sleep(5)  # 대기시간 변경 가능

            iframe = driver.find_element(By.ID , "mainFrame") # id가 mainFrame이라는 요소를 찾아내고 -> iframe임
            driver.switch_to.frame(iframe) # 이 iframe이 내가 찾고자하는 html을 포함하고 있는 내용

            source = driver.page_source
            html = BeautifulSoup(source, "html.parser")
            # 검색결과 확인용
            # with open("Output.txt", "w") as text_file:
            #     text_file.write(str(html))

            # 기사 텍스트만 가져오기
            content = html.select("div.se-main-container")
            #  list합치기
            content = ''.join(str(content))

            # html태그제거 및 텍스트 다듬기
            content = re.sub(pattern=pattern1, repl='', string=content)
            pattern2 = """[\n\n\n\n\n// flash 오류를 우회하기 위한 함수 추가\nfunction _flash_removeCallback() {}"""
            content = content.replace(pattern2, '')
            content = content.replace('\n', '')
            content = content.replace('\u200b', '')
            contents.append(content)

        name = '['+namedata+']blog.csv'
        print(name)
        news_df = pd.DataFrame({'title': titles, 'content': contents, 'date': postdate})
        news_df.to_csv('blog.csv', index=False, encoding='utf-8-sig')
        os.rename('blog.csv', name)
    except:
        contents.append('error')
        news_df = pd.DataFrame({'title': titles, 'content': contents, 'date': postdate})
        news_df.to_csv('blog.csv', index=False, encoding='utf-8-sig')
    if(loopend == 1):
        break
    else:
        loopend -= 1
# Out:
# 100대 명산 채크 [명산]/ 일반 검색 [Enter]
# 검색할 키워드를 입력해주세요:설악산
#
# 크롤링을 시작 위치를 입력해주세요. (기본값:1, 최대값:100):1
#
# 시작부터 마지막 위치 입력해주세요. (기본값:1, 최대값:100):5
# 1  ~ 6 페이지 까지 크롤링을 진행 합니다
#
# 한번에 가져올 페이지 개수를 입력해주세요.(기본값:10, 최대값: 100):5
#
# 한번에 가져올 페이지 :  5 페이지
# https://blog.naver.com/hahahahahaho/223401465938
# https://blog.naver.com/darkdac/223400998196
# https://blog.naver.com/zzzz1n/223388335640
# https://blog.naver.com/rolo_ggo/223394543631
# https://blog.naver.com/qufzhd12/223265250013
# https://blog.naver.com/tpgusl0511/223391239991
# https://blog.naver.com/dladngud22/223399515485
# https://blog.naver.com/armeise5/223406043289
# https://blog.naver.com/nailstan/223407122503
# https://blog.naver.com/solhouse100/223383771753
# https://blog.naver.com/hong273526/223381588822
# https://blog.naver.com/chs153chs/223384341520
# https://blog.naver.com/nivearein/223323281155
# https://blog.naver.com/gjdhrwk/223373615709
# https://blog.naver.com/1215_sy/223364625390
# https://blog.naver.com/animalkara/223270735314
# https://blog.naver.com/ninamath/223395445701
# https://blog.naver.com/lifehealer_sujin/223371409375
# https://blog.naver.com/travelgeo/223370226909
# https://blog.naver.com/coco1268/223357423645
# https://blog.naver.com/armeise5/223403798774
# https://blog.naver.com/wild_flower8/223360719035
# https://blog.naver.com/bongjourlife/223402518279
# https://blog.naver.com/zmfnwm333/223358919692
# https://blog.naver.com/hwonnara/223380600367
# https://blog.naver.com/jinkmidh/223392244771
# https://blog.naver.com/nacf5915/223357821963
# https://blog.naver.com/samchun2g/223341647768
# https://blog.naver.com/jeongld/223381026227
# [설악산]blog.csv

# %%
pd.read_csv('[설악산]blog.csv')
# Out:
#                                             title  \
# 0   [강원도/속초] 여자 혼자 등산하기 좋은 코스! &lt; 설악산 울산바위 &gt;
# 1         그레이트지리 3일차 (feat : 마치며.. 설악산 종주를 꿈꾸다..)
# 2               설악산 숙소 켄싱턴호텔 설악 디럭스 트윈룸 조식 디너 후기!
# 3               속초 설악산 숙소/ 켄싱턴호텔 설악(스튜디오 디럭스룸...
# 4                         양양 호텔 설악산 바로 앞 오색그린야드호텔
# 5                         설악산맛집 여행중 최고의 한끼 설악산로한우
# 6              속초 설악산 맛집 설악산로한우 고급한우식당 속초 고기집...
# 7               속초 여행 설악산 케이블카 운영시간 및 요금 예약방법...
# 8                    속초 여행 추천 코스 설악산 국립공원 속초 여행코스
# 9                      속초 여행 선물 중앙시장에서 구입한 설악산단풍빵
# 10                       속초 설악산국립공원 케이블카 시간표 타는 곳
# 11                    설악산 등산코스 추천 Top3, 초보에게는 비추천
# 12                     설악산 등산코스 신흥사 비선대 금강굴 초보 추천
# 13                      강원도여행 설악산,양양 낙산사,대관령 양떼목장
# 14                      설악산 최단코스 오색약수-대청봉 원점회귀 코스
# 15             &quot;설악산 국립공원 케이블카&quot; 절대 안됩니다!
# 16                설악산 근처 숙소 켄싱턴호텔 설악 카페 애비로드 부대시설
# 17                    설악케이블카 정상 아이와 대만족했던 설악산국립공원
# 18               설악산 국립공원 오색약수터 주차장 주전골~용소폭포 등산코스
# 19                                  2.17설악산 토왕성폭포
# 20          켄싱턴호텔 설악 속초 여행 숙소 설악산 전망 카페 애비로드와...
# 21                            [설악산 서북능선]나홀로 귀때기청봉
# 22                            설악산 비룡폭포-토왕성폭포 등산코스
# 23               강원도 속초여행코스 설악산 케이블카 후기 (이용요금,주차)
# 24                                 딱 20년 전 설악산 설경
# 25                                  20240317 설악산2
# 26                             겨울 설악산, 토왕성폭포 비룡폭포
# 27           강원도 여행지 추천 속초 여행코스 설악산 국립공원 케이블카...
# 28                        속초가볼만한 곳, 3월 초 눈 덮인 설악산
#
#                                               content      date
# 0   [날이 따뜻해지고 푸릇푸릇 새싹이 올라오면 설레지요 왜냐구요? 산타기 좋으니깐요!!...  20240331
# 1   [#완주 #그레이트지리 #천왕봉 #3일종주 #주의사항 #보급 #워딩 #준비 #2pe...  20240331
# 2   [설악산 숙소 켄싱턴호텔 설악오늘은 설악산 국립공원을 도보 5분으로갈 수 있는 설악...  20240319
# 3   [설악산 전망 호텔 레트로 감성 있는 켄싱턴호텔  설악산 가깝고 포토존이 많아알찬 ...  20240325
# 4   [안녕하세요~ 두덩입니다 :)오늘은 설악산 등산하시는 분들이 묵기 좋은 양양 호텔을...  20231214
# 5   [안녕하세요 여행이 즐거운 효닝닝입니다 :)요즘 여행에 푹 빠져있는 효닝닝은내일 제...  20240322
# 6   [속초 설악산 맛집 설안산로한우고급한우식당 속초 고기집 식도락 여행  설안산로한우 ...  20240329
# 7   [속초 여행 설악산 케이블카 운영시간 및 요금 예약방법 주차까지 알아봄안녕하세요? ...  20240404
# 8   [속초 여행 추천 코스 설악산 국립공원 속초 여행코스벚꽃 개화시기에 속초여행을 계획...  20240405
# 9   [속초 여행 선물설악산단풍빵아이들 개학 전 당일치기로 다녀온 속초여행속초를 겁도 없...  20240314
# 10  [여행일 : 2024. 3. 8 / 글, 사진 : 아공3월 춘설이 폭설주의보로 바뀐...  20240313
# 11  [설악산 등산코스 중 추천드리는 3곳, 하지만 초보들에게는 비추천 합니다. 개인적으...  20240315
# 12  [설악산 등산코스 신흥사 비선대 금강굴 초보 추천겨울이 오기만을 손꼽아 기다렸습니다...  20240115
# 13  [강원도여행 이틀째지난번 강원도에 내린 눈이 70cm~1m정도 라더니정말 폭설이었네...  20240305
# 14  [ 설악산 대청봉(1,707.9m)  강원특별자치도 양양군 서면 오색리에 있는 설악...  20240225
# 15  ["설악산 국립공원 케이블카" 절대 안됩니다!⠀⠀어제(20일) 강원도 양양군에서는 ...  20231121
# 16  [속초, 설악산 호텔Kensington Hotel Prologue날씨가 따뜻해진 주...  20240326
# 17  [속초 여행에서 빠질 수 없는 설악산국립공원에서 케이블카를 탔습니다:) 드디어 설악...  20240303
# 18  [설악산은 인제, 양양, 속초, 고성에 걸쳐서 분포하고 있는 언제 찾아도 좋은 명산...  20240301
# 19  [설악산 소공원&gt;육담폭포&gt;비룡폭포&gt;&gt;토왕성폭포날마다 한걸음씩 ...  20240218
# 20  [ 켄싱턴호텔 설악 속초여행 숙소 설악산전망 카페 애비로드와 조식 후기안녕하세요? ...  20240402
# 21  [안녕하세요 와플입니다  오늘은 설악산 서북능선 귀때기청봉이야기 입니다 지금껏 다녔...  20240221
# 22  [설악산 비룡폭포코스--&gt; 토왕성폭포 전망대 등산코스는 등산거리 2.7km(왕...  20240401
# 23  [강원도속초여행속초여행코스속초가볼만한곳설악산케이블카설악산케이블카주차설악산케이블카이용...  20240220
# 24  [눈쌓인 동해 해변엊그제 주말에도 영하의 날씨였었죠.이번주는 계속 포근한 영상의 날...  20240312
# 25  [사진이 50개 밖에 안 올라가서... 새벽에 깨서 찍은 호텔 뷰인데정말 그림같이 ...  20240322
# 26  [바다낚시 지인모임에서 각자 스케줄 때문에 다 빠지고 혼자 동해 고성으로 어구가자미...  20240219
# 27  [ 강원도 여행지 추천 속초 여행코스 설악산 국립공원 케이블카 타고 권금성 눈구경....  20240202
# 28  [ 설악산 국립공원입장료: 무료주차요금: 6,000원(설악산 소공원주차장) 50m©...  20240312
